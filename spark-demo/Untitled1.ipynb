# %%
from pyspark.sql import SparkSession

# Initialize Spark
spark = SparkSession.builder.appName("DemoSparkApp").getOrCreate()

# Tell Spark to only log actual ERRORS, hiding the WARN clutter
spark.sparkContext.setLogLevel("ERROR")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/12 05:18:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/06/12 05:18:07 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
