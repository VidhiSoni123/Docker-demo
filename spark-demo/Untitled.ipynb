# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("DemoSparkApp").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/12 05:09:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/06/12 05:09:17 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
data = [1, 2, 3, 4]

# %%
rdd = spark.sparkContext.parallelize(data)

# %%
spark = SparkSession.builder.appName("DemoSparkApp").getOrCreate()

# %%
for element in rdd.collect():
    print(element)
# Out:
# 1
# 2
# 3
# 4
